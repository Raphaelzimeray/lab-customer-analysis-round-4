# %% [markdown]
# # Lab Customer analysis round 4

# %% [markdown]
# In today's lesson we talked about continuous distributions (mainly normal distribution), linear regression and how multicollinearity can impact the model. In this lab, we will test your knowledge on those things using the marketing_customer_analysis.csv file. You have been using the same data in the previous labs (round 2 and 3). You can continue using the same jupyter file. The file can be found in the files_for_lab folder.
#
# Get the data
# Use the jupyter file from the last lab (Customer Analysis Round 3)
#
# Complete the following task
# Check the data types of the columns.
# Get the numeric data into dataframe called numerical and categorical columns in a dataframe called categoricals. (You can use np.number and np.object to select the numerical data types and categorical data types respectively)
# Now we will try to check the normality of the numerical variables visually
# Use seaborn library to construct distribution plots for the numerical variables
# Use Matplotlib to construct histograms
# Do the distributions for different numerical variables look like a normal distribution
# For the numerical variables, check the multicollinearity between the features. Please note that we will use the column total_claim_amount later as the target variable.
# Drop one of the two features that show a high correlation between them (greater than 0.9). Write code for both the correlation matrix and for seaborn heatmap. If there is no pair of features that have a high correlation, then do not drop any features

# %%
# pour aller à la ligne dans un markdown, il faut faire 3X espace, et entrer

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("marketing_customer_analysis.csv")

# %%
data.shape
# Out:
# (9134, 24)

# %%
data.columns = data.columns.str.lower()

# %%
data
# Out:
#      customer       state  customer lifetime value response  coverage  \
# 0     BU79786  Washington              2763.519279       No     Basic
# 1     QZ44356     Arizona              6979.535903       No  Extended
# 2     AI49188      Nevada             12887.431650       No   Premium
# 3     WW63253  California              7645.861827       No     Basic
# 4     HB64268  Washington              2813.692575       No     Basic
# ...       ...         ...                      ...      ...       ...
# 9129  LA72316  California             23405.987980       No     Basic
# 9130  PK87824  California              3096.511217      Yes  Extended
# 9131  TD14365  California              8163.890428       No  Extended
# 9132  UP19263  California              7524.442436       No  Extended
# 9133  Y167826  California              2611.836866       No  Extended
#
#      education effective to date employmentstatus gender  income  ...  \
# ...

# %%
print("Nombre de lignes : " + str(len(data.index)))


for serie in data:
    print("\n" + data[serie].name + " : " + 
          str(len(data[serie].unique())) + " Valeur unique")
    print(data[serie].value_counts())
    #print("data type : ", file_1[serie].dtype
# Out:
# Nombre de lignes : 9134
#
# customer : 9134 Valeur unique
# BU79786    1
# PU81096    1
# CO75086    1
# WW52683    1
# XO38850    1
#           ..
# HS14476    1
# YL91587    1
# CT18212    1
# EW35231    1
# Y167826    1
# Name: customer, Length: 9134, dtype: int64
#
# state : 5 Valeur unique
# California    3150
# Oregon        2601
# Arizona       1703
# Nevada         882
# Washington     798
# Name: state, dtype: int64
#
# customer lifetime value : 8041 Valeur unique
# 7200.664877     6
# 17497.522010    6
# 2248.449633     6
# 8092.876960     6
# 6057.072080     6
#                ..
# 9162.063169     1
# 2374.147419     1
# 6874.848270     1
# 9934.865795     1
# 2611.836866     1
# Name: customer lifetime value, Length: 8041, dtype: int64
#
# response : 2 Valeur unique
# No     7826
# Yes    1308
# Name: response, dtype: int64
#
# coverage : 3 Valeur unique
# Basic       5568
# Extended    2742
# Premium      824
# Name: coverage, dtype: int64
#
# ...

# %%
data.head(2)
# Out:
#   customer       state  customer lifetime value response  coverage education  \
# 0  BU79786  Washington              2763.519279       No     Basic  Bachelor
# 1  QZ44356     Arizona              6979.535903       No  Extended  Bachelor
#
#   effective to date employmentstatus gender  income  ...  \
# 0           2/24/11         Employed      F   56274  ...
# 1           1/31/11       Unemployed      F       0  ...
#
#   months since policy inception number of open complaints  number of policies  \
# 0                             5                         0                   1
# 1                            42                         0                   8
#
#       policy type        policy  renew offer type  sales channel  \
# 0  Corporate Auto  Corporate L3            Offer1          Agent
# 1   Personal Auto   Personal L3            Offer3          Agent
#
#   total claim amount  vehicle class vehicle size
# 0         384.811147   Two-Door Car      Medsize
# ...

# %%
data.dtypes
# Out:
# customer                          object
# state                             object
# customer lifetime value          float64
# response                          object
# coverage                          object
# education                         object
# effective to date                 object
# employmentstatus                  object
# gender                            object
# income                             int64
# location code                     object
# marital status                    object
# monthly premium auto               int64
# months since last claim            int64
# months since policy inception      int64
# number of open complaints          int64
# number of policies                 int64
# policy type                       object
# policy                            object
# renew offer type                  object
# sales channel                     object
# total claim amount               float64
# vehicle class                     object
# ...

# %%
numerical = data.select_dtypes(include=[np.number])
categorical = data.select_dtypes(include=[np.object])
# Out:
# /var/folders/f3/h898q6xn2tng47j0vchzh1tw0000gn/T/ipykernel_99346/3980222669.py:2: DeprecationWarning: `np.object` is a deprecated alias for the builtin `object`. To silence this warning, use `object` by itself. Doing this will not modify any behavior and is safe.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   categorical = data.select_dtypes(include=[np.object])

# %%
numerical
# Out:
#       customer lifetime value  income  monthly premium auto  \
# 0                 2763.519279   56274                    69
# 1                 6979.535903       0                    94
# 2                12887.431650   48767                   108
# 3                 7645.861827       0                   106
# 4                 2813.692575   43836                    73
# ...                       ...     ...                   ...
# 9129             23405.987980   71941                    73
# 9130              3096.511217   21604                    79
# 9131              8163.890428       0                    85
# 9132              7524.442436   21941                    96
# 9133              2611.836866       0                    77
#
#       months since last claim  months since policy inception  \
# 0                          32                              5
# 1                          13                             42
# ...

# %%
categorical
# Out:
#      customer       state response  coverage education effective to date  \
# 0     BU79786  Washington       No     Basic  Bachelor           2/24/11
# 1     QZ44356     Arizona       No  Extended  Bachelor           1/31/11
# 2     AI49188      Nevada       No   Premium  Bachelor           2/19/11
# 3     WW63253  California       No     Basic  Bachelor           1/20/11
# 4     HB64268  Washington       No     Basic  Bachelor            2/3/11
# ...       ...         ...      ...       ...       ...               ...
# 9129  LA72316  California       No     Basic  Bachelor           2/10/11
# 9130  PK87824  California      Yes  Extended   College           2/12/11
# 9131  TD14365  California       No  Extended  Bachelor            2/6/11
# 9132  UP19263  California       No  Extended   College            2/3/11
# 9133  Y167826  California       No  Extended   College           2/14/11
#
#      employmentstatus gender location code marital status     policy type  \
# ...

# %% [markdown]
# # Now we will try to check the normality of the numerical variables visually
# Use seaborn library to construct distribution plots for the numerical variables

# %%
import seaborn as sbn

# %%
numerical.columns
# Out:
# Index(['customer lifetime value', 'income', 'monthly premium auto',
#        'months since last claim', 'months since policy inception',
#        'number of open complaints', 'number of policies',
#        'total claim amount'],
#       dtype='object')

# %% [markdown]
# Boxplot ou boite à moustache permet de résumer une variable de manière simple et visuel, d'identifier les valeurs extrêmes et de comprendre la répartition des observations.
# La valeur centrale du graphique est la médiane (il existe autant de valeur supérieures qu'inférieures à cette valeur dans l'échantillon).
# Les bords du rectangle sont les quartiles (Pour le bord inférieur, un quart des observations ont des valeurs plus petites et trois quart ont des
# valeurs plus grandes, le bord supérieur suit le même raisonnement).
# Les extrémités des moustaches sont calculées en utilisant 1.5 fois l'espace interquartile (la distance entre le 1er et le 3ème quartile).

# %%
fig = plt.gcf()
fig.set_size_inches(20,4)
meanprops = {'marker':'o', 'markeredgecolor':'black',
            'markerfacecolor':'firebrick'}
sbn.boxplot(x=numerical['customer lifetime value'], color ='gold', orient='h', medianprops = {'color':"green"},showmeans=True,meanprops=meanprops)
plt.title('Distribution de la colonne customer lifetime value ',color='black',fontsize=18)
# Out:
# Text(0.5, 1.0, 'Distribution de la colonne customer lifetime value ')

# %%
fig = plt.gcf()
fig.set_size_inches(20,4)
meanprops = {'marker':'o', 'markeredgecolor':'black',
            'markerfacecolor':'firebrick'}

sbn.boxplot(x=numerical['income'], color ='gold', orient='h', medianprops = {'color':"green"},showmeans=True,meanprops=meanprops)
plt.title('Distribution de la colonne income ',color='black',fontsize=18)
# Out:
# Text(0.5, 1.0, 'Distribution de la colonne income ')

# %% [markdown]
# Essayons de faire une boucle sur toutes les colonnes afin de construire chaque boxplot

# %%
for serie in numerical:
    fig = plt.gcf()
    fig.set_size_inches(20,4)
    meanprops = {'marker':'o', 'markeredgecolor':'black',
                'markerfacecolor':'firebrick'}

    #plt.style.use('dark_background')
    sbn.boxplot(x=numerical[serie], color ='gold', orient='h', medianprops = {'color':"green"},showmeans=True,meanprops=meanprops)
    plt.title('Distribution de la colonne customer lifetime value ',color='black',fontsize=18)

# %% [markdown]
# Le resultat n'est pas satisfaisant car toutes les boites à moustache se superposent, on ne voit rien

# %%
# essayons avec seaborn
plt.figure(figsize=(17, 5))
sbn.boxplot(data=numerical,orient='v')
plt.show()

# %% [markdown]
# Il y a trop de difference de valeurs entre les variables, observons les min et les max de chaques variables car l'axe des y est le même pour toutes les variables

# %%
numerical.describe()
# Out:
#        customer lifetime value        income  monthly premium auto  \
# count              9134.000000   9134.000000           9134.000000
# mean               8004.940475  37657.380009             93.219291
# std                6870.967608  30379.904734             34.407967
# min                1898.007675      0.000000             61.000000
# 25%                3994.251794      0.000000             68.000000
# 50%                5780.182197  33889.500000             83.000000
# 75%                8962.167041  62320.000000            109.000000
# max               83325.381190  99981.000000            298.000000
#
#        months since last claim  months since policy inception  \
# count              9134.000000                    9134.000000
# mean                 15.097000                      48.064594
# std                  10.073257                      27.905991
# min                   0.000000                       0.000000
# ...

# %% [markdown]
# Ce serait formidable si nous pouvions dessiner une boîte à moustaches où chaque colonne a son propre axe y. De cette façon, les colonnes avec des échelles plus grandes n'affecteront pas visuellement les autres.

# %%
# Avec Pandas matplotlib

numerical.plot(
    kind='box',  # type de graphique
    subplots=True, # pour pouvoir mettre plusieurs boxplot sur le même graphique
    sharey=False, # ne pas partager l'axe des y
    figsize=(17, 5) # taille du graphique
)

# increase spacing between subplots
plt.subplots_adjust(wspace=0.7)
#plt.xticks(color='red')
plt.show()

# %% [markdown]
# Use Matplotlib to construct histograms

# %%
numerical['income']
# Out:
# 0       56274
# 1           0
# 2       48767
# 3           0
# 4       43836
#         ...
# 9129    71941
# 9130    21604
# 9131        0
# 9132    21941
# 9133        0
# Name: income, Length: 9134, dtype: int64

# %%
numerical['income'].plot(figsize = (20,7))
# Out:
# <Axes: >

# %% [markdown]
# en utilisant plot ca n'est pas comprehensible, essayons de faire un histogramme

# %%
numerical['income'].hist()
plt.grid(color = 'grey')

# %% [markdown]
# # Maintenant, visualisons tout cela pour l'ensemble des variables

# %%
numerical.hist(figsize=(30, 20))
plt.grid(color = 'grey')

# %% [markdown]
# # Do the distributions for different numerical variables look like a normal distribution

# %% [markdown]
# In statistics, kernel density estimation (KDE) is a non-parametric way to estimate the probability density function (PDF) of a random variable. This function uses Gaussian kernels and includes automatic bandwidth determination.

# %%
numerical['income'].plot.kde(figsize = (10,5))
plt.grid(color = 'grey')

# %%
numerical.plot(figsize=(30, 20))
# Out:
# <Axes: >

# %% [markdown]
# # C'est illisible car tout se place sur le même graphique
# Essayons de séparer les graphiques avec subplots

# %%
# Avec Pandas matplotlib
numerical.plot.kde(
    #kind='box',  # type de graphique
    subplots=True, # permet de mettre plusieurs graphique sur le même support
    sharex=False, # ne pas partager l'axe des x
    figsize=(10, 20) # taille du graphique
)

# increase spacing between subplots
plt.subplots_adjust(wspace=3)
#plt.xticks(color='red')
plt.show()

# %% [markdown]
# # For the numerical variables, check the multicollinearity between the features. Please note that we will use the column total_claim_amount later as the target variable.

# %%
# On utilise la méthode corr() pour calculer s'il existe une corrélation entre chaque variables quantitatives
corrMatrix = numerical.corr()
fig = plt.gcf()
fig.set_size_inches(10,8)
sbn.heatmap(corrMatrix, annot=True, cmap="Greens")
plt.xticks(rotation=15,fontsize=12)
plt.yticks(fontsize=12)
plt.title('MATRICE DE CORRELATION R (PEARSON) - Numerical datas', fontsize=18, color='black')
#plt.savefig('Mission3_1-Matrice-R-Quanti.png')
plt.show()
